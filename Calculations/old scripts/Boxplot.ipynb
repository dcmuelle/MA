# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import matplotlib.dates as mdates

# %%
plt.rcParams["figure.figsize"] = (15,8) #set size of plot
plt.rcParams.update({'font.size': 22})

# %%
os.chdir('/home/MA/Calculations/CH/')

# %%
results_2010 = pd.read_pickle('results_2010.pkl')
results_2011 = pd.read_pickle('results_2011.pkl')
results_2012 = pd.read_pickle('results_2012.pkl')
results_2013 = pd.read_pickle('results_2013.pkl')
results_2014 = pd.read_pickle('results_2014.pkl')
results_2015 = pd.read_pickle('results_2015.pkl')
results_2016 = pd.read_pickle('results_2016.pkl')

# %%
results_optimization_2010 = pd.read_pickle('results_optimization_2010.pkl')
results_optimization_2011 = pd.read_pickle('results_optimization_2011.pkl')
results_optimization_2012 = pd.read_pickle('results_optimization_2012.pkl')
results_optimization_2013 = pd.read_pickle('results_optimization_2013.pkl')
results_optimization_2014 = pd.read_pickle('results_optimization_2014.pkl')
results_optimization_2015 = pd.read_pickle('results_optimization_2015.pkl')
results_optimization_2016 = pd.read_pickle('results_optimization_2016.pkl')

# %%
results = results_2010.append(results_2011).append(results_2012).append(results_2013).append(results_2014).append(results_2015).append(results_2016)

# %%
results_optimization = results_optimization_2010.append(results_optimization_2011).append(results_optimization_2012).append(results_optimization_2013).append(results_optimization_2014).append(results_optimization_2015).append(results_optimization_2016)

# %%
results.boxplot(by ='battery_size', column =['ESOI'], grid = False)
plt.suptitle('');

# %%
results.boxplot(by ='battery_size', column =['EROI_grid_curtailed'], grid = False)
plt.suptitle('');

# %%
results_optimization.boxplot(by ='curtailment', column =['optimal_battery_size'], grid = False)
plt.suptitle('');

# %%
results_optimization.boxplot(by ='curtailment', column =['net_CO2_savings'], grid = False)
plt.suptitle('');
